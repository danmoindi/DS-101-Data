# %%
import pandas as pd

# Define the file path
data=pd.read_excel("FSI-2023-DOWNLOAD.xlsx", sheet_name=0, header=0)

# Display the first five rows (head)
print("Head of the dataset:")
print(data.head())

# Display the last five rows (tail)
print("\nTail of the dataset:")
print(data.tail())

# Display a random sample of 5 rows
print("\nRandom Sample:")
print(data.sample(5))
# Out:
# Head of the dataset:
#                      Country  Year Rank  Total  S1: Demographic Pressures  \
# 0                    Somalia  2023  1st  111.9                       10.0
# 1                      Yemen  2023  2nd  108.9                        9.6
# 2                South Sudan  2023  3rd  108.5                        9.7
# 3  Congo Democratic Republic  2023  4th  107.2                        9.7
# 4                      Syria  2023  5th  107.1                        7.4
#
#    S2: Refugees and IDPs  C3: Group Grievance  \
# 0                    9.0                  8.7
# 1                    9.6                  8.8
# 2                   10.0                  8.6
# 3                    9.8                  9.4
# 4                    9.1                  9.1
#
#    E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 0                               8.6                      9.1          9.5
# 1                               6.4                      7.9          9.9
# 2                               6.5                      8.6          8.6
# 3                               6.4                      8.4          8.1
# 4                               8.0                      6.5          9.6
#
#    P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 0                   9.6                  9.8               9.0
# 1                   9.8                  9.6               9.6
# 2                   9.8                  9.7               8.7
# 3                   9.3                  9.3               9.3
# 4                  10.0                  9.0               9.1
#
#    C1: Security Apparatus  C2: Factionalized Elites  X1: External Intervention
# 0                     9.5                      10.0                        9.1
# 1                     8.6                       9.9                        9.2
# 2                     9.9                       9.2                        9.2
# 3                     8.8                       9.6                        9.1
# 4                     9.4                       9.9                       10.0
#
# Tail of the dataset:
#          Country  Year   Rank  Total  S1: Demographic Pressures  \
# 174  Switzerland  2023  175th   17.8                        2.4
# 175  New Zealand  2023  176th   16.7                        1.1
# 176      Finland  2023  177th   16.0                        1.7
# 177      Iceland  2023  178th   15.7                        1.5
# 178       Norway  2023  179th   14.5                        1.4
#
#      S2: Refugees and IDPs  C3: Group Grievance  \
# 174                    3.2                  2.1
# 175                    1.2                  2.0
# 176                    1.9                  0.3
# 177                    1.5                  0.5
# 178                    1.7                  3.1
#
#      E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 174                               1.0                      2.4          1.6
# 175                               1.6                      2.6          2.6
# 176                               1.5                      1.6          2.7
# 177                               1.6                      1.5          2.6
# 178                               0.7                      1.4          1.4
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 174                   0.3                  1.6               0.4
# 175                   0.5                  1.1               0.5
# 176                   0.4                  1.0               0.5
# 177                   0.4                  0.9               0.4
# 178                   0.4                  1.0               0.4
#
#      C1: Security Apparatus  C2: Factionalized Elites  \
# 174                     1.4                       1.0
# 175                     1.6                       1.4
# 176                     2.0                       1.4
# 177                     0.4                       1.8
# 178                     1.4                       1.1
#
#      X1: External Intervention
# 174                        0.4
# 175                        0.5
# 176                        1.0
# 177                        2.6
# 178                        0.5
#
# Random Sample:
#           Country  Year   Rank  Total  S1: Demographic Pressures  \
# 19        Burundi  2023   20th   94.2                        8.7
# 153     Mauritius  2023  154th   38.0                        3.1
# 161        France  2023  162nd   28.8                        3.1
# 81           Fiji  2023   82nd   70.2                        4.6
# 20   Burkina Faso  2023   21st   94.0                        8.3
#
#      S2: Refugees and IDPs  C3: Group Grievance  \
# 19                     8.0                  6.7
# 153                    1.6                  5.0
# 161                    2.4                  6.4
# 81                     3.2                  5.4
# 20                     8.2                  5.8
#
#      E3: Human Flight and Brain Drain  E2: Economic Inequality  E1: Economy  \
# 19                                5.2                      7.2          8.8
# 153                               4.2                      3.1          5.0
# 161                               2.0                      2.9          3.4
# 81                                7.6                      5.0          7.5
# 20                                7.0                      8.3          7.2
#
#      P1: State Legitimacy  P2: Public Services  P3: Human Rights  \
# 19                    9.1                  8.0               8.6
# 153                   2.3                  3.1               3.6
# 161                   1.0                  1.2               1.1
# 81                    6.1                  4.2               5.4
# 20                    7.4                  8.6               7.0
#
#      C1: Security Apparatus  C2: Factionalized Elites  \
# 19                      7.8                       8.5
# 153                     1.0                       3.1
# 161                     2.9                       1.9
# 81                      6.4                       8.2
# 20                      9.3                       8.2
#
#      X1: External Intervention
# 19                         7.6
# 153                        2.9
# 161                        0.5
# 81                         6.6
# 20                         8.7
